# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# -yglet                             1.5.16
# -ym                                0.7.4
# absl-py                            0.13.0
# alabaster                          0.7.12
# alembic                            1.6.5
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arviz                              0.11.2
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# astunparse                         1.6.3
# async-generator                    1.10
# atari-py                           0.2.9
# atomicwrites                       1.4.0
# ...

# %% [markdown]
# # Test OpenCV Samples

# %%
import cv2

# %%
# Histogram sample
# !cd opencv-4.5.4/samples/python & python hist.py
# Out:
#  This is a sample for histogram plotting for RGB images and grayscale images for better understanding of colour distribution
#
# Benefit : Learn how to draw histogram of images
#           Get familier with cv.calcHist, cv.equalizeHist,cv.normalize and some drawing functions
#
# Level : Beginner or Intermediate
#
# Functions : 1) hist_curve : returns histogram of an image drawn as curves
#             2) hist_lines : return histogram of an image drawn as bins ( only for grayscale images )
#
# Usage : python hist.py <image_file>
#
# Abid Rahman 3/14/12 debug Gary Bradski
#
# usage : python hist.py <image_file>
#  Histogram plotting
#
#     Keymap :
#
#     a - show histogram for color image in curve mode
#
#     b - show histogram in bin mode
#
#     c - show equalized histogram (always in bin mode)
#
#     d - show histogram for gray image in curve mode
#
#     e - show histogram for a normalized image in curve mode
#
#     Esc - exit
#
#
# a
# a
# b
# ...

# %%
# Optical flow sample
# !cd opencv-4.5.4/samples/python & python opt_flow.py 7
# Out:
# example to show optical flow
#
# USAGE: opt_flow.py [<video_source>]
#
# Keys:
#  1 - toggle HSV flow visualization
#  2 - toggle glitch
#
# Keys:
#     ESC    - exit
#
# ...
# Done
# [ WARN:0] global C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-sn_xpupm\opencv\modules\core\src\utils\samples.cpp (61) cv::samples::findFile cv::samples::findFile('lena.jpg') => 'D:\Programming\OpenCV\opencv-4.5.4\samples\python/../..\samples/data\lena.jpg'

# %%
# People Detect sample
# !cd opencv-4.5.4/samples/python & peopledetect.py Dog_and_Me.png

# %% [markdown]
# ![Dog_is_me_and_I_am_dog.png](attachment:Dog_is_me_and_I_am_dog.png)
